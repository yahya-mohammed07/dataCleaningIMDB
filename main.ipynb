# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("messy_IMDB_dataset_cleaned.csv",
                   sep=';',  # ; seperated
                   quotechar='"',    # quoted values handled
                   encoding='latin-1',  # encode
                   na_values=['Nan', 'NULL', 'Not Applicable', 'Inf',
                              '', 'None'],  # null values handled
                   )
data
# Out:
#     IMBD title ID                Original title  Release year  \
# 0       tt0111161      The Shawshank Redemption    1995-02-10
# 1       tt0068646                 The Godfather    09 21 1972
# 2       tt0468569               The Dark Knight   23 -07-2008
# 3       tt0071562        The Godfather: Part II    1975-09-25
# 4       tt0110912                  Pulp Fiction    1994-10-28
# ..            ...                           ...           ...
# 96      tt0070735                     The Sting    1974-03-21
# 97      tt0082096                      Das Boot    1982-03-18
# 98      tt0059578  /Per qualche dollaro in piÃ¹    1965-12-20
# 99      tt1832382       Jodaeiye Nader az Simin    2011-10-21
# 100     tt0045152           Singin' in the Rain    1953-02-05
#
#                           Genre Duration       Country Content Rating  \
# 0                         Drama      142           USA              R
# 1                  Crime, Drama      175           USA              R
# ...

# %%
data = data.drop_duplicates()
data
# Out:
#     IMBD title ID                Original title  Release year  \
# 0       tt0111161      The Shawshank Redemption    1995-02-10
# 1       tt0068646                 The Godfather    09 21 1972
# 2       tt0468569               The Dark Knight   23 -07-2008
# 3       tt0071562        The Godfather: Part II    1975-09-25
# 4       tt0110912                  Pulp Fiction    1994-10-28
# ..            ...                           ...           ...
# 96      tt0070735                     The Sting    1974-03-21
# 97      tt0082096                      Das Boot    1982-03-18
# 98      tt0059578  /Per qualche dollaro in piÃ¹    1965-12-20
# 99      tt1832382       Jodaeiye Nader az Simin    2011-10-21
# 100     tt0045152           Singin' in the Rain    1953-02-05
#
#                           Genre Duration       Country Content Rating  \
# 0                         Drama      142           USA              R
# 1                  Crime, Drama      175           USA              R
# ...

# %%
data = data.drop(columns='Unnamed: 8')
data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11432\3871836808.py in ?()
# ----> 1 data = data.drop(columns='Unnamed: 8')
#       2 data
#
# d:\Programming\Master\dataCleaning\env\Lib\site-packages\pandas\core\frame.py in ?(self, labels, axis, index, columns, level, inplace, errors)
#    5577                 weight  250.0   150.0
#    5578         falcon  speed   320.0   250.0
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#    5584             index=index,
#
# d:\Programming\Master\dataCleaning\env\Lib\site-packages\pandas\core\generic.py in ?(self, labels, axis, index, columns, level, inplace, errors)
#    4784         obj = self
#    4785
#    4786         for axis, labels in axes.items():
# ...

# %%
data['Original title'] = data['Original title'].str.strip("123._/") # remove numbers and some chars
data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\Programming\Master\dataCleaning\env\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:191, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:234, in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# File index.pyx:242, in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# File index.pyx:134, in pandas._libs.index._unpack_bool_indexer()
#
# KeyError: 'Original title'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[46], line 1
# ...

# %%
data
# Out:
#            NaN                          NaN           NaN  \
# 0    tt0111161     The Shawshank Redemption    1995-02-10
# 1    tt0068646                The Godfather    09 21 1972
# 2    tt0468569              The Dark Knight   23 -07-2008
# 3    tt0071562       The Godfather: Part II    1975-09-25
# 4    tt0110912                 Pulp Fiction    1994-10-28
# ..         ...                          ...           ...
# 96   tt0070735                    The Sting    1974-03-21
# 97   tt0082096                     Das Boot    1982-03-18
# 98   tt0059578  Per qualche dollaro in piÃ¹    1965-12-20
# 99   tt1832382      Jodaeiye Nader az Simin    2011-10-21
# 100  tt0045152          Singin' in the Rain    1953-02-05
#
#                             NaN  NaN           NaN    NaN  \
# 0                         Drama  142           USA      R
# 1                  Crime, Drama  175           USA      R
# 2          Action, Crime, Drama  152            US  PG-13
# ...
